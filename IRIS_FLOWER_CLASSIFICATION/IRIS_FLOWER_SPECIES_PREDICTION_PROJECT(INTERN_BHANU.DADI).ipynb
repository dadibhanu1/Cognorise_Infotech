# %% [markdown]
# ### -----------------------------------------------------TASK-1------------------------------------------------------

# %% [markdown]
# ###         IRIS FLOWER  PREDICTION CLASSIFICATION PROJECT

# %%
#importing libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ### LOADING THE DATASET

# %%
#loading the dataset
dataset=pd.read_csv(r"Iris.csv")

# %%
dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### EDA (EXPLORATORY DATA ANALYSIS)

# %% [markdown]
# ### STEP-1
# ### UNDERSTANDING THE DATASET.

# %%
dataset.shape  # dataset contains 150 rows & 6 columns
# Out:
# (150, 6)

# %%
dataset.info() # to know the datatypes of the columns in the dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
dataset.describe()  # to know the basic statistics of the dataset
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
dataset["Species"].unique() # there are the 3  different types of species present in the dataset.
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
dataset.columns # these are the cols of the dataset
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
dataset.head(5)  # gives top 5 records of the dataset.
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dataset.tail(5)  # gives the last 5 records of the dataset.
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# ## STEP-2
# ### DATA CLEANING

# %% [markdown]
# ### REMOVING UNWANTED COLUMNS

# %%
# AS WE KNOW THAT, THE "ID"  COLUMN ,IS NOT CONTRIBUTING  TO THE TARGET COL-(SPECIES)
# SO,WE CAN DROP THE COLUMN.

# %%
dataset.drop(columns=["Id"] , inplace = True)# drop---- used to delete the column from the dataset.
                                                # inplace = True---- used for updating the dataset.

# %%
dataset.shape
# Out:
# (150, 5)

# %% [markdown]
# ### HANDLING MISSING VALUES

# %%
# checking for missing values

dataset.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# we can observe that there are no missing values in the dataset,  so no need to handle missing values in this case.

# %% [markdown]
# ### HANDLING OUTLIERS

# %%
# checking for outliers
# we can plot "boxplots"  for checking outliers

# %%
#importing the required libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
outliers=[dataset["SepalLengthCm"],dataset["SepalWidthCm"],dataset["PetalLengthCm"],dataset["PetalWidthCm"]]

plt.boxplot(outliers)
plt.show()

# %% [markdown]
#  We can see that there are only few outliers present in "SepalWidthCm" column,but the outliers are not that much far away from regular points , and there are very few in number,so no need to handle outliers in this case.
#  And in others there are no outliers present.

# %% [markdown]
# ### STEP-3
# ### VISUALIZATION

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %% [markdown]
# ### BOX PLOT

# %%
dataset.boxplot(figsize=(10,5))
plt.show()

# %% [markdown]
# ### HIST PLOT

# %%
dataset.hist(figsize=(8,8))
plt.show()

# %%
sns.countplot(dataset["Species"])
# Out:
# C:\Users\India\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %% [markdown]
# ### PIE CHART

# %%
grp_species=dataset.groupby(by="Species")["Species"].count()

# %%
grp_species
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
plt.pie(grp_species,labels=["Iris-setosa","Iris-versicolor" ,"Iris-virginica"],autopct='%1.0f%%')
plt.show()

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %% [markdown]
# ### SCATTERPLOT

# %%
sns.scatterplot(x=dataset["SepalLengthCm"],y=dataset["SepalWidthCm"],hue = dataset["Species"])
plt.show()

# %% [markdown]
# OBSERVATION::
#
# We can observe that the length & width of the sepals of Iris-setosa is very large.
#
# And for Iris-versicolor and Iris-virginica the length and width of sepals are moderate .

# %%
sns.scatterplot(dataset["PetalLengthCm"],dataset["PetalWidthCm"],hue=dataset["Species"])
plt.show()
# Out:
# C:\Users\India\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# OBSERVATION::
#
# FROM THE ABOVE SCATTERPLOT, WE CAN OBSERVE THAT FOR "IRIS-VIRGINICA" THE LENGTH  AND WIDTH OF THE PETAL IS VERY LARGE , WHEN COMAPRED TO ALL OTHER SPECIES.
#
# FOR IRIS-SETOSA THE LENGTH & WIDTH OF THE PETAL'S  IS VERY SMALL. FOR IRIS-VERSICOLOR THE LENGTH & WIDTH IS MODERATE.

# %%
plt.figure(figsize=(10,5))
sns.pairplot(dataset,hue="Species")
plt.show()

# %% [markdown]
# #### SPILLTING THE DATA INTO INDEPENDENT & DEPENDENT VARIABLES

# %%
dataset.head(3)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa

# %%
X=dataset.drop(columns=["Species"])

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y=dataset["Species"]

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %% [markdown]
# ### SPILLTING THE DATA INTO "TRAIN" AND "TEST" DATA

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,x_test,y_train,y_test=train_test_split(X,y,train_size=0.75,random_state=35)

# %%
#this the training data to train the model

# %%
X_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 115            6.4           3.2            5.3           2.3
# 119            6.0           2.2            5.0           1.5
# 98             5.1           2.5            3.0           1.1
# 46             5.1           3.8            1.6           0.2
# 34             4.9           3.1            1.5           0.1
# ..             ...           ...            ...           ...
# 57             4.9           2.4            3.3           1.0
# 147            6.5           3.0            5.2           2.0
# 139            6.9           3.1            5.4           2.1
# 33             5.5           4.2            1.4           0.2
# 15             5.7           4.4            1.5           0.4
#
# [112 rows x 4 columns]

# %%
y_train
# Out:
# 115     Iris-virginica
# 119     Iris-virginica
# 98     Iris-versicolor
# 46         Iris-setosa
# 34         Iris-setosa
#             ...
# 57     Iris-versicolor
# 147     Iris-virginica
# 139     Iris-virginica
# 33         Iris-setosa
# 15         Iris-setosa
# Name: Species, Length: 112, dtype: object

# %%
#this is the test data to test the model

# %%
x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 95             5.7           3.0            4.2           1.2
# 61             5.9           3.0            4.2           1.5
# 128            6.4           2.8            5.6           2.1
# 72             6.3           2.5            4.9           1.5
# 40             5.0           3.5            1.3           0.3
# 104            6.5           3.0            5.8           2.2
# 146            6.3           2.5            5.0           1.9
# 64             5.6           2.9            3.6           1.3
# 78             6.0           2.9            4.5           1.5
# 49             5.0           3.3            1.4           0.2
# 84             5.4           3.0            4.5           1.5
# 144            6.7           3.3            5.7           2.5
# 17             5.1           3.5            1.4           0.3
# 120            6.9           3.2            5.7           2.3
# ...

# %%
y_test
# Out:
# 95     Iris-versicolor
# 61     Iris-versicolor
# 128     Iris-virginica
# 72     Iris-versicolor
# 40         Iris-setosa
# 104     Iris-virginica
# 146     Iris-virginica
# 64     Iris-versicolor
# 78     Iris-versicolor
# 49         Iris-setosa
# 84     Iris-versicolor
# 144     Iris-virginica
# 17         Iris-setosa
# 120     Iris-virginica
# 25         Iris-setosa
# 113     Iris-virginica
# 80     Iris-versicolor
# 38         Iris-setosa
# 13         Iris-setosa
# 6          Iris-setosa
# 58     Iris-versicolor
# 91     Iris-versicolor
# 143     Iris-virginica
# 86     Iris-versicolor
# 43         Iris-setosa
# 31         Iris-setosa
# 10         Iris-setosa
# 123     Iris-virginica
# 30         Iris-setosa
# 118     Iris-virginica
# 7          Iris-setosa
# 70     Iris-versicolor
# 106     Iris-virginica
# 22         Iris-setosa
# 75     Iris-versicolor
# 134     Iris-virginica
# 12         Iris-setosa
# 130     Iris-virginica
# Name: Species, dtype: object

# %%
x_test.shape
# Out:
# (38, 4)

# %% [markdown]
# ## BUILDING THE ML-MODEL

# %% [markdown]
# ### 1.LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
lor_model=LogisticRegression()

# %%
lor_model.fit(X_train,y_train)
# Out:
# C:\Users\India\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ### PREDICTION

# %%
y_pred_train=lor_model.predict(X_train)

# %%
y_pred_train
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
# ...

# %%
y_pred=lor_model.predict(x_test)

# %%
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %% [markdown]
# ### EVALUATION

# %% [markdown]
# ### ACCURACY SCORE

# %%
from sklearn.metrics import accuracy_score

# %%
train_score=accuracy_score(y_train,y_pred_train)

# %%
train_score
# Out:
# 0.9732142857142857

# %%
test_score=accuracy_score(y_test,y_pred)

# %%
test_score
# Out:
# 0.9473684210526315

# %% [markdown]
# ### CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix

# %%
cm_train_score=confusion_matrix(y_train,y_pred_train)

# %%
from mlxtend.plotting import plot_confusion_matrix

# %%
plot_confusion_matrix(cm_train_score,class_names=['Iris-versicolor','Iris-setosa','Iris-virginica'])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %%
cm_test_score=confusion_matrix(y_pred,y_test)

# %%
plot_confusion_matrix(cm_test_score,class_names=['Iris-versicolor','Iris-setosa','Iris-virginica'])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %% [markdown]
# ### REALTIME PREDICTION

# %%
X.loc[100,:]
# Out:
# SepalLengthCm    6.3
# SepalWidthCm     3.3
# PetalLengthCm    6.0
# PetalWidthCm     2.5
# Name: 100, dtype: float64

# %%
data=list(X.loc[100,:])

# %%
data
# Out:
# [6.3, 3.3, 6.0, 2.5]

# %%
data=np.array([data])

# %%
data
# Out:
# array([[6.3, 3.3, 6. , 2.5]])

# %%
lor_model.predict(data)
# Out:
# C:\Users\India\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Iris-virginica'], dtype=object)

# %%
y.iloc[100]
# Out:
# 'Iris-virginica'

# %% [markdown]
# ### CROSSVALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_score=cross_val_score(lor_model,X_train,y_train,cv=9,n_jobs=-1,verbose=10,scoring='accuracy')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0755s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   3 out of   9 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   9 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   6 out of   9 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   7 out of   9 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    0.1s finished

# %%
cv_score
# Out:
# array([0.92307692, 0.92307692, 1.        , 0.92307692, 1.        ,
#        1.        , 1.        , 1.        , 1.        ])

# %%
np.mean(cv_score)
# Out:
# 0.9743589743589745

# %% [markdown]
# ### CLASSIFICATION REPORT

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train,y_pred_train))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        36
# Iris-versicolor       0.97      0.95      0.96        38
#  Iris-virginica       0.95      0.97      0.96        38
#
#        accuracy                           0.97       112
#       macro avg       0.97      0.97      0.97       112
#    weighted avg       0.97      0.97      0.97       112

# %%
print(classification_report(y_pred,y_test))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       0.92      0.92      0.92        12
#  Iris-virginica       0.92      0.92      0.92        12
#
#        accuracy                           0.95        38
#       macro avg       0.94      0.94      0.94        38
#    weighted avg       0.95      0.95      0.95        38

# %% [markdown]
# ## 2. KNN(K-nearest neighbours)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model=KNeighborsClassifier()

# %%
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## PREDICTION

# %%
y_pred_train=knn_model.predict(X_train)
# Out:
# C:\Users\India\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
y_pred_train
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
# ...

# %%
y_pred=knn_model.predict(x_test)
# Out:
# C:\Users\India\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %% [markdown]
# ## EVALUATION

# %%
from sklearn.metrics import accuracy_score

# %%
train_score=accuracy_score(y_train,y_pred_train)

# %%
train_score
# Out:
# 0.9910714285714286

# %%
test_score=accuracy_score(y_pred,y_test)

# %%
test_score
# Out:
# 0.9210526315789473

# %% [markdown]
# ## CONFUSION MATRIX

# %%
cm_train_score=confusion_matrix(y_train,y_pred_train)

# %%
plot_confusion_matrix(cm_train_score,class_names=['Iris-versicolor','Iris-setosa','Iris-virginica'])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %%
cm_test=confusion_matrix(y_pred,y_test)

# %%
plot_confusion_matrix(cm_test,class_names=['Iris-versicolor','Iris-setosa','Iris-virginica'])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %% [markdown]
# ### REALTIME PREDICTION

# %%
y.iloc[50]
# Out:
# 'Iris-versicolor'

# %%
SepalLengthCm=7.0
SepalWidthCm=3.2
PetalLengthCm=4.7
PetalWidthCm=1.4

# %%
data={
    'SepalLengthCm' : [SepalLengthCm],
    'SepalWidthCm'  : [SepalWidthCm],
    'PetalLengthCm' : [PetalLengthCm],
    'PetalWidthCm'  :[PetalWidthCm]
}

# %%
data=pd.DataFrame(data)

# %%
data
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            7.0           3.2            4.7           1.4

# %%
knn_model.predict(data)
# Out:
# C:\Users\India\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# array(['Iris-versicolor'], dtype=object)

# %% [markdown]
# ### CROSSVALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_scores=cross_val_score(knn_model,X_train,y_train,cv=4,n_jobs=-1,
    verbose=2,scoring='accuracy')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished

# %%
cv_scores
# Out:
# array([1.        , 0.96428571, 0.96428571, 1.        ])

# %%
np.mean(cv_scores)
# Out:
# 0.9821428571428572

# %% [markdown]
# ## SVM (SUPPORT VECTOR MACHINES)

# %% [markdown]
# ### SVC(SUPPORT VECTOR CLASSIFIER)

# %%
from sklearn.svm import SVC

# %%
svc_model=SVC(kernel='linear')

# %%
svc_model.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ### PREDICTION

# %%
y_pred_train=svc_model.predict(X_train)

# %%
y_pred_train
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
# ...

# %%
y_pred=svc_model.predict(x_test)

# %%
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %% [markdown]
# ## EVALUATION

# %% [markdown]
# ### ACCURACY SCORE

# %%
train_score=accuracy_score(y_train,y_pred_train)

# %%
train_score
# Out:
# 0.9910714285714286

# %%
test_score=accuracy_score(y_test,y_pred)

# %%
test_score
# Out:
# 0.9736842105263158

# %% [markdown]
# ## CONFUSION MATRIX

# %%
cm_train_score=confusion_matrix(y_train,y_pred_train)

# %%
plot_confusion_matrix(cm_train_score,class_names=['Iris-versicolor','Iris-setosa','Iris-virginica'])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %%
cm_test=confusion_matrix(y_pred,y_test)

# %%
plot_confusion_matrix(cm_test,class_names=['Iris-versicolor','Iris-setosa','Iris-virginica'])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %% [markdown]
# ### CROSSVALIDATION

# %%
cv_scores=cross_val_score(svc_model,X_train,y_train,cv=8,n_jobs=-1,verbose=8,scoring='accuracy')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.0s finished

# %%
cv_scores
# Out:
# array([1.        , 1.        , 1.        , 0.92857143, 1.        ,
#        1.        , 1.        , 1.        ])

# %%
np.mean(cv_scores)
# Out:
# 0.9910714285714286

# %% [markdown]
# ### 4.DECISIONTREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc_model=DecisionTreeClassifier()

# %%
dtc_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# ### PREDICTION

# %%
y_pred_train=dtc_model.predict(X_train)

# %%
y_pred_train
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
# ...

# %%
y_pred=dtc_model.predict(x_test)

# %%
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %% [markdown]
# ## EVALUATION

# %% [markdown]
# ### ACCURACY SCORE

# %%
train_score=accuracy_score(y_pred_train,y_train)

# %%
train_score
# Out:
# 0.9821428571428571

# %%
test_score=accuracy_score(y_pred,y_test)

# %%
test_score
# Out:
# 0.9473684210526315

# %% [markdown]
# ### CONFUSION MATRIX

# %%
cm_train_score=confusion_matrix(y_pred_train,y_train)

# %%
plot_confusion_matrix(cm_train_score,class_names=dataset["Species"].unique())
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %%
cm_test=confusion_matrix(y_pred,y_test)

# %%
plot_confusion_matrix(cm_test,class_names=dataset["Species"].unique())
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %% [markdown]
# ### CLASSIFICATION REPORT

# %%
print(classification_report(y_train,y_pred_train))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        36
# Iris-versicolor       1.00      0.95      0.97        38
#  Iris-virginica       0.95      1.00      0.97        38
#
#        accuracy                           0.98       112
#       macro avg       0.98      0.98      0.98       112
#    weighted avg       0.98      0.98      0.98       112

# %%
print(classification_report(y_pred,y_test))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       0.92      0.92      0.92        12
#  Iris-virginica       0.92      0.92      0.92        12
#
#        accuracy                           0.95        38
#       macro avg       0.94      0.94      0.94        38
#    weighted avg       0.95      0.95      0.95        38

# %% [markdown]
# ## HYPERPARAMETER TUNING

# %% [markdown]
# ### GRIDSEARCH CV

# %%
max_depth = np.linspace(3, 10, 6,dtype="int")
min_samples_split = [2, 5, 10, 15, 30, 35]
min_samples_leaf = [1, 2, 5, 10, 15]
criterion = ["gini","entropy"]
min_impurity_decrease = [0.0001, 0.0005,0.1]

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc_model=DecisionTreeClassifier()

# %%
param_grid={
    "max_depth" :max_depth ,
    "min_samples_split" :min_samples_split,
    "min_samples_leaf":min_samples_leaf,
    "criterion":criterion,
    "min_impurity_decrease" : min_impurity_decrease
}

# %%
gsv=GridSearchCV(dtc_model,param_grid,cv=5,n_jobs=-1,verbose=10)

# %%
gsv
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([ 3,  4,  5,  7,  8, 10]),
#                          'min_impurity_decrease': [0.0001, 0.0005, 0.1],
#                          'min_samples_leaf': [1, 2, 5, 10, 15],
#                          'min_samples_split': [2, 5, 10, 15, 30, 35]},
#              verbose=10)

# %%
gsv.fit(X_train,y_train) ###### THROWING ERROR BECOZ "GRIDSEARCH CV " IS NOT CAPABLE TO EXECUTE LARGE NO.OF COMBINTIONS
# Out:
# Fitting 5 folds for each of 1080 candidates, totalling 5400 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([ 3,  4,  5,  7,  8, 10]),
#                          'min_impurity_decrease': [0.0001, 0.0005, 0.1],
#                          'min_samples_leaf': [1, 2, 5, 10, 15],
#                          'min_samples_split': [2, 5, 10, 15, 30, 35]},
#              verbose=10)

# %%
gsv.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=3, min_impurity_decrease=0.0001)

# %%
gsv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 3,
#  'min_impurity_decrease': 0.0001,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
gsv.best_score_
# Out:
# 0.9648221343873518

# %%
###APPLYING TO MODEL

# %%
# #'criterion': 'gini',
#  'max_depth': 3,
#  'min_impurity_decrease': 0.0001,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2

# %%
best_params= {'criterion': 'gini',
 'max_depth': 3,
 'min_impurity_decrease': 0.0001,
 'min_samples_leaf': 1,
 'min_samples_split': 2}

# %%
dtc_model=DecisionTreeClassifier(criterion=best_params['criterion'],
                               max_depth=best_params['max_depth'],
                               min_samples_split=best_params['min_samples_split'],
                              min_samples_leaf=best_params['min_samples_leaf'],
                               min_impurity_decrease=best_params['min_impurity_decrease'])

# %%
dtc_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_impurity_decrease=0.0001)

# %% [markdown]
# ### CROSSVALIDATION

# %%
cv_scores=cross_val_score(dtc_model,X_train,y_train,cv=12,n_jobs=-1,scoring='accuracy')

# %%
cv_scores
# Out:
# array([0.9       , 0.9       , 0.9       , 1.        , 1.        ,
#        1.        , 1.        , 0.88888889, 1.        , 1.        ,
#        1.        , 1.        ])

# %%
np.mean(cv_scores)
# Out:
# 0.9657407407407407

# %% [markdown]
# ## 5.RANDOMFOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc_model=RandomForestClassifier()

# %%
rfc_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ## PREDICTION

# %%
y_pred_train=rfc_model.predict(X_train)

# %%
y_pred_train
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
# ...

# %%
y_pred=rfc_model.predict(x_test)

# %%
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %% [markdown]
# ### EVALUATION

# %% [markdown]
# ### ACCURACY SCORE

# %%
train_score=accuracy_score(y_pred_train,y_train)

# %%
train_score
# Out:
# 0.9642857142857143

# %%
test_score=accuracy_score(y_pred,y_test)

# %%
test_score
# Out:
# 0.9210526315789473

# %% [markdown]
# ### CONFUSION MATIX

# %%
cm_train=confusion_matrix(y_pred_train,y_train)

# %%
plot_confusion_matrix(cm_train,class_names=dataset["Species"].unique())
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %%
cm_test=confusion_matrix(y_pred,y_test)

# %%
plot_confusion_matrix(cm_test,class_names=dataset["Species"].unique())
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %% [markdown]
# ###  HYPERPARAMETER TUNING

# %% [markdown]
# ### GRIDSEARCH CV

# %%
n_estimators=[3,4,5,6,7,8,9,10]
criterion=['gini','entropy']
max_depth = np.linspace(3, 10, 6,dtype="int")#linspace--means diving the no.s into equal parts
min_samples_split = [2, 5, 10, 15, 30, 35]
min_samples_leaf = [1, 2, 5, 10, 15]
min_impurity_decrease = np.linspace(0.0001, 0.0005, 8)

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={"n_estimators":n_estimators,"criterion":criterion,"max_depth" :max_depth ,"min_samples_split" :min_samples_split,
            "min_samples_leaf":min_samples_leaf,
          "min_impurity_decrease" : min_impurity_decrease}

# %%
gsv=GridSearchCV(rfc_model,param_grid=param_grid,cv=3,n_jobs=-1,verbose=10)

# %%
gsv
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([ 3,  4,  5,  7,  8, 10]),
#                          'min_impurity_decrease': array([0.0001    , 0.00015714, 0.00021429, 0.00027143, 0.00032857,
#        0.00038571, 0.00044286, 0.0005    ]),
#                          'min_samples_leaf': [1, 2, 5, 10, 15],
#                          'min_samples_split': [2, 5, 10, 15, 30, 35],
#                          'n_estimators': [3, 4, 5, 6, 7, 8, 9, 10]},
#              verbose=10)

# %%
#gsv.fit(X_train,y_train) ##### THROWING ERROR BECOZ "GRIDSEARCH CV " IS NOT CAPABLE TO EXECUTE LARGE NO.OF COMBINTIONS

# %% [markdown]
# ### RANDOMSEARCH CV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rsv=RandomizedSearchCV(rfc_model,param_distributions=param_grid,n_iter=700,
                      cv=5,n_jobs=-1,verbose=5)

# %%
rsv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 700 candidates, totalling 3500 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=700,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': array([ 3,  4,  5,  7,  8, 10]),
#                                         'min_impurity_decrease': array([0.0001    , 0.00015714, 0.00021429, 0.00027143, 0.00032857,
#        0.00038571, 0.00044286, 0.0005    ]),
#                                         'min_samples_leaf': [1, 2, 5, 10, 15],
#                                         'min_samples_split': [2, 5, 10, 15, 30,
#                                                               35],
#                                         'n_estimators': [3, 4, 5, 6, 7, 8, 9,
#                                                          10]},
#                    verbose=5)

# %%
rsv.best_params_
# Out:
# {'n_estimators': 7,
#  'min_samples_split': 15,
#  'min_samples_leaf': 5,
#  'min_impurity_decrease': 0.0005,
#  'max_depth': 3,
#  'criterion': 'entropy'}

# %%
rsv.best_score_
# Out:
# 0.9913043478260869

# %%
###APPLYING TO  MODEL

# %%
best_params={'n_estimators': 7,
 'min_samples_split': 15,
 'min_samples_leaf': 5,
 'min_impurity_decrease': 0.0005,
 'max_depth': 3,
 'criterion': 'entropy'}

# %%
rfc_model=RandomForestClassifier(criterion=best_params['criterion'],
                              max_depth=best_params['max_depth'],
                              min_impurity_decrease=best_params['min_impurity_decrease'],
                              min_samples_leaf=best_params['min_samples_leaf'],
                              min_samples_split=best_params['min_samples_split'],
                              n_estimators=best_params['n_estimators'])

# %%
rfc_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=3,
#                        min_impurity_decrease=0.0005, min_samples_leaf=5,
#                        min_samples_split=15, n_estimators=7)

# %% [markdown]
# ### CROSSVALIDATION

# %%
cv_scores=cross_val_score(rfc_model,X_train,y_train,cv=5,verbose=2,n_jobs=-1,scoring='accuracy')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.1s finished

# %%
cv_scores
# Out:
# array([0.91304348, 0.95652174, 1.        , 1.        , 1.        ])

# %%
np.mean(cv_scores)
# Out:
# 0.9739130434782609

# %% [markdown]
# ### BAR PLOT- ACCURACY SCORES OF TRAIN & TEST DATA  OF ALL THE MODEL'S

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Algorithms=["lor_model","knn_model","svc_model","dtc_model","rfc_model"]
Accuracy_train_scores=[0.973,0.991,0.991,0.982,0.964]
Accuracy_test_scores=[0.947,0.921,0.973,0.947,0.921]

# %%
x = np.arange(len(Algorithms))
bar_width=0.35
width = 0.35

# %%
plt.figure(figsize=(10,6))
plt.bar(x - bar_width/2, Accuracy_train_scores, bar_width, label='Accuracy_train_scores', color='#ADD8E6',alpha=0.7)
plt.bar(x + bar_width/2,Accuracy_test_scores, bar_width, label=' Accuracy_test_scores', color='#3366cc', alpha=0.5)


plt.xlabel("Algorithms")
plt.ylabel("Accuracy Scores")
plt.title('Accuracy Scores of Different Algorithms for Flower species prediction')
plt.xticks(x,Algorithms)
plt.legend(loc='lower left')
#plt.show()


for i in range(len(Algorithms)):
    plt.annotate(Accuracy_train_scores[i],(x[i] - width/2,Accuracy_train_scores[i]),ha='center',  fontsize=10)
    plt.annotate(f'{Accuracy_test_scores[i]}', (x[i] + width/2,Accuracy_test_scores[i]), ha='center', fontsize=10)
plt.show()

# %% [markdown]
# ### CROSS VALIDATION SCORES OF ALL ALGORITHMS.

# %%
Algorithms=["lor_model","knn_model","svc_model","dtc_model","rfc_model"]
cv_scores=[0.974,0.982,0.991,0.965,0.973]
width=0.35

# %%
plt.figure(figsize=(10,6))
plt.bar(Algorithms,cv_scores,width=bar_width,color="#ADD8E6")
for i, v in enumerate(cv_scores):
    plt.text(i, v, str(v), ha='center', va='bottom', fontsize=10)
plt.xlabel('Algorithms')
plt.ylabel('cv scores')
plt.title('CV scores')
#plt.tight_layout()
plt.show()

# %% [markdown]
# __________________________________________________________________________________________________________________________
#
# ## CONCLUSION
#
# From my Project,I can conclude that all the model's are predicting very well.
# The accuracy scores of both train & test data also good.
# But among them all, SVC (support vector classifier) model is working very well to the unseen data.
# So, compared to other models SVC is best,but also other model predictions are also toogood.
# This project helps us to easily predict from which species the flower is belonged.
# I evaluated  Acuuracy score and also confusion matrix metrics ,the peformance of the metrices also too good.
# Along with this,for classsification problem we can also use metrics to evaluate so,I used classification report -it shows the other metrics result as well.
#
# The decisiontree Classifier and RandomForestClassifier  both the model's faced overfitting issue, so in that case i applied "Hyperparameter Tuning" Techniques like "Gridsearch CV" in order to overcome  overfitting the issue.
#
# "Hyperparameter Tuning" are the techniques used when our model's facing overfitting issue.So.to avoid the issues we can simply apply one of these techniques to improve the model's performance.
#
# Cross Validation- is also a techinque used in Machine Learning  model's to evaluate how our model is performing to new or unseen data.
#
# So, all the above ML  model's can be applied to the given dataset.
# By giving specific measurements of flower we can easily predict which species the flower is belonged.
#
# ________________________________________________________________________________________________________________________
